# %%
type(12)
# Out:
# int

# %%
type(2.14)
# Out:
# float

# %%
type('Hello, Python 101!')
# Out:
# str

# %%
type(12.0)
# Out:
# float

# %%
type(-1)
# Out:
# int

# %%
type(0)
# Out:
# int

# %%
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
float(2)
# Out:
# 2.0

# %%
type(float(2))
# Out:
# float

# %%
int(1.1)
# Out:
# 1

# %%
int(1.6)
# Out:
# 1

# %%
int(1.9)
# Out:
# 1

# %%
int('1')
# Out:
# 1

# %%
int('1 or 2 people')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-cd59a23aeda5> in <cell line: 1>()
# ----> 1 int('1 or 2 people')
#
# ValueError: invalid literal for int() with base 10: '1 or 2 people'

# %%
float('1.2')
# Out:
# 1.2

# %%
str(1)
# Out:
# '1'

# %%
str(1.2)
# Out:
# '1.2'

# %%
True
# Out:
# True

# %%
T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-29704cb91324> in <cell line: 1>()
# ----> 1 T
#
# NameError: name 'T' is not defined

# %%
False
# Out:
# False

# %%
type(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6f4d8242c3d0> in <cell line: 1>()
# ----> 1 type(true)
#
# NameError: name 'true' is not defined

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
type(6/2)
# Out:
# float

# %%
type(8/2)
# Out:
# float

# %%
type(8//2)
# Out:
# int

# %%
type(7//2)
# Out:
# int

# %%
type(10.9+7.2*61)
# Out:
# float

# %%
type(102+2938-1982)
# Out:
# int

# %%
5*5
# Out:
# 25

# %%
80/8
# Out:
# 10.0

# %%
55/6
# Out:
# 9.166666666666666

# %%
55//6
# Out:
# 9

# %%
50+70//6
# Out:
# 61

# %%
(50+70)/6
# Out:
# 20.0

# %%
(50+70)//6
# Out:
# 20

# %%
x = 50+60+70
x
# Out:
# 180

# %%
y = 70-90/6
y
# Out:
# 55.0

# %%
x = x/6
print(x)
# Out:
# 5.0

# %%
x
# Out:
# 5.0

# %%
total_min = 10+10+50
total_min
# Out:
# 70

# %%
float(total_min)
# Out:
# 70.0

# %%
a=5
a
# Out:
# 5

# %%
total_hours = total_min/7
total_hours
# Out:
# 10.0

# %%
total_hours = (50+70+80)/70
total_hours
# Out:
# 2.857142857142857

# %%
x = 4+5+6
x
# Out:
# 15

# %%
y=5+8+9
y
# Out:
# 22

# %%
z=y-x
z
# Out:
# 7

# %%
panjang=20.5
lebar=25
tinggi=10

keliling=2*(panjang+lebar)
luas=panjang/lebar
volume=panjang*lebar*tinggi

print("Panjang      =", panjang)
print("Lebar        =", lebar)
print('Tinggi       =', tinggi)
print('Keliling     =', keliling)
print('Luas         =', luas)
print('Volume       =', volume)
# Out:
# Panjang      = 20.5
# Lebar        = 25
# Tinggi       = 10
# Keliling     = 91.0
# Luas         = 0.82
# Volume       = 5125.0

# %%
S   = 85+75
print('1. Rata-rata nilai Shafira       =', S/2)
HA=75+90+70+75
print('2. Jumlah nilai Hanif dan Andi   =', HA)
W=85*2/2
D=85*2/2
H=(80+75)/2
N=(95+80)/2
print('3. Rata-rata nilai               =')
print('   a. Widya  :', W)
print('   b. Dhanar :', D)
print('   c. Hikma  :', H)
print('   D. Nedia  :', N)
print('4. Rata-rata kalkulus            =', (85+80+75+95+85+75+70+85+80)/9)
print('5. Rata-rata statistika          +', (75+90+80+80+85+90+75+85+75)/9)
# Out:
# 1. Rata-rata nilai Shafira       = 80.0
# 2. Jumlah nilai Hanif dan Andi   = 310
# 3. Rata-rata nilai               =
#    a. Widya  : 85.0
#    b. Dhanar : 85.0
#    c. Hikma  : 77.5
#    D. Nedia  : 87.5
# 4. Rata-rata kalkulus            = 81.11111111111111
# 5. Rata-rata statistika          + 81.66666666666667

# %%
G=30000
T=28*8*G
R=0.1*T
print('1. Gaji bulan Agustus   : Rp', T)
print('2. Tunjangan            : Rp', R)
print('3. Gaji total + lembur  : Rp', T+R+50000)
# Out:
# 1. Gaji bulan Agustus   : Rp 6720000
# 2. Tunjangan            : Rp 672000.0
# 3. Gaji total + lembur  : Rp 7442000.0
