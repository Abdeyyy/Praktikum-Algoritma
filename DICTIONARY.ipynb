# %%
#WEEKLY EXERCISE 2
data={
    'nama' : 'Muhammad Abdillah Aziz',
    'kelas': 'Rombel 1',
    'lahir':'1 Januari 2006',
    'telp':'089601450863',
    'alamat':'Jl. Sawo Dalangan',
    'hobi':['1. Bermain game', '2. Membaca buku']
}

for i in range(1):
  print("Nama   : ", data['nama'])
  print('Kelas  : ', data['kelas'])
  print('Tanggal lahir :', data['lahir'])
  print('Telepon: ', data['telp'])
  print('Alamat : ', data['alamat'])
  print('Hobi   : ')
  for x in data['hobi']:
    print(f" {x}")
# Out:
# Nama   :  Muhammad Abdillah Aziz
# Kelas  :  Rombel 1
# Tanggal lahir : 1 Januari 2006
# Telepon:  089601450863
# Alamat :  Jl. Sawo Dalangan
# Hobi   :
#  1. Bermain game
#  2. Membaca buku
