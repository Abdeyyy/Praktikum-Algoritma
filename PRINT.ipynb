# %%
print(Heyyyooooo, Python world!)
# Out:
# Heyyyooooo, Python world!

# %%
print(""Universitas Tidar"")
# Out:
#   File "<ipython-input-3-c16a32833850>", line 1
#     print(""Universitas Tidar"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
print(Hello, Python!)
# Out:
#   File "<ipython-input-5-2b499f1590ec>", line 1
#     print(Hello, Python!)
#                        ^
# SyntaxError: invalid syntax

# %%
print('Hello, Python!')
# Out:
# Hello, Python!

# %%
print('Hi')
# Out:
# Hi

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
print("Nama : Muhammad Abdillah Aziz")
# Out:
# Nama : Muhammad Abdillah Aziz

# %%
print("Nama : Muhammad Abdillah Aziz")
print("NPM : 2420506017")
print("Alamat : Dalangan RT05/RW08, Kramat Utara ")
print('Tinggi badan : 169')
print('Berat badan : 49')
# Out:
# Nama : Muhammad Abdillah Aziz
# NPM : 2420506017
# Alamat : Dalangan RT05/RW08, Kramat Utara
# Tinggi badan : 169
# Berat badan : 49

# %%
print("Nama             : Muhammad Abdillah Aziz")
print()
print('NPM              : 2420506017')
print()
print('Alamat           : Dalangan RT05/RW08, Kramat Utara, Magelang Utara')
print()
print('Tinggi Badan     : 169')
print()
print('Berat badan      : 49')
# Out:
# Nama             : Muhammad Abdillah Aziz
#
# NPM              : 2420506017
#
# Alamat           : Dalangan RT05/RW08, Kramat Utara, Magelang Utara
#
# Tinggi Badan     : 169
#
# Berat badan      : 49

# %%
print('\033[1mUNIVERSITAS TIDAR\033[0m')
print('Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah diteteapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.')
print()
print('\033[1mJURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI\033[0m')
print('   1. S1 Teknik Elektro \033[3m(Bachelor of Electrical Engineering)\033[0m')
print('   2. S1 Teknologi Informasi \033[3m(Bachelor of Information Technology)\033[0m')
print('   3. S1 Teknik Mekatronika \033[3m(Bachelor of Mechatronics Engineering)\033[0m')
# Out:
# UNIVERSITAS TIDAR
# Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri yang telah diteteapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.
#
# JURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI
#    1. S1 Teknik Elektro (Bachelor of Electrical Engineering)
#    2. S1 Teknologi Informasi (Bachelor of Information Technology)
#    3. S1 Teknik Mekatronika (Bachelor of Mechatronics Engineering)

# %%
print('         *')
print("        *_*")
print('       *_*_*')
print('      *_*_*_*')
print('     *_*_*_*_*')
# Out:
#          *
#         *_*
#        *_*_*
#       *_*_*_*
#      *_*_*_*_*
