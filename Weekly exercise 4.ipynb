# %%
#WEEKLY EXERCISE 1
umur = int(input('Masukkan umur :'))
if (umur>=17) :
  print('Boleh membuat SIM')
else:
  print('Tidak boleh membuat SIM')
# Out:
# Masukkan umur :16
# Tidak boleh membuat SIM

# %%
#WEEKLY EXERCISE 2
nilai=float(input('Masukkan nilai :'))
if nilai>=90:
  print('A')
elif nilai>=80:
  print('B+')
elif nilai>=70:
  print('B')
elif nilai>=60:
    print("C+")
elif nilai>=50:
  print('C')
elif nilai>=40:
  print('D')
else:
  print("E")
# Out:
# Masukkan nilai :100
# A

# %%
#WEEKLY EXERCISE 3
nilai=float(input('Masukkan nilai :'))
if (nilai>=80) and (nilai<=100):
  print('A')
elif (nilai>=77.50) and (nilai<=79.99):
  print('A-')
elif (nilai>=75) and (nilai<=77,49):
  print('A/B')
elif (nilai>=72.50) and (nilai<=74.99):
    print("B+")
elif (nilai>=70) and (nilai<=72.49):
  print('B')
elif (nilai>=67.50) and (nilai<=69.99):
  print('B-')
elif (nilai>=65) and (nilai<=67.49):
  print('B/C')
elif (nilai>=62.50) and (nilai<=64.99):
  print('C+')
elif (nilai>=62.50) and (nilai<=64.99):
  print('C+')
elif (nilai>=60) and (nilai<=62.49):
  print('C')
elif (nilai>=55) and (nilai<=59.99):
  print('C-')
elif (nilai>=50) and (nilai<=54.99):
  print('C/D')
elif (nilai>=45) and (nilai<=49.99):
  print('D+')
elif (nilai>=40) and (nilai<=44.99):
  print('D')
else:
  print("E")
# Out:
# Masukkan nilai :70
# B
